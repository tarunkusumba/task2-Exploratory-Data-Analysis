# %% [markdown]
# **STEP 1: Downloading the Cleaned titanic Dataset ✅**

# %% [markdown]
# **STEP 2: Loading the dataset ✅**

# %%
import pandas as pd

df = pd.read_csv('titanic_cleaned.csv')
print(df.head())
print(df.info())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            3         1       3
# 2            4         1       1
# 3            5         0       3
# 4            6         0       3
#
#                                            Name  Sex       Age  SibSp  Parch  \
# 0                       Braund, Mr. Owen Harris    1 -0.565736      1      0
# 1                        Heikkinen, Miss. Laina    0 -0.258337      0      0
# 2  Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  0.433312      1      0
# 3                      Allen, Mr. William Henry    1  0.433312      0      0
# 4                              Moran, Mr. James    1 -0.104637      0      0
#
#              Ticket      Fare  Embarked
# 0         A/5 21171 -0.502445         2
# 1  STON/O2. 3101282 -0.488854         2
# 2            113803  0.420730         2
# 3            373450 -0.486337         2
# 4            330877 -0.478116         1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 718 entries, 0 to 717
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  718 non-null    int64
#  1   Survived     718 non-null    int64
#  2   Pclass       718 non-null    int64
#  3   Name         718 non-null    object
#  4   Sex          718 non-null    int64
#  5   Age          718 non-null    float64
#  6   SibSp        718 non-null    int64
#  7   Parch        718 non-null    int64
#  8   Ticket       718 non-null    object
#  9   Fare         718 non-null    float64
#  10  Embarked     718 non-null    int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 61.8+ KB
# None

# %% [markdown]
# **STEP 3: Statistics ✅**

# %%
print(df.describe())
print(df.median(numeric_only=True))
print(df.std(numeric_only=True))
# Out:
#        PassengerId    Survived      Pclass         Sex         Age  \
# count   718.000000  718.000000  718.000000  718.000000  718.000000
# mean    447.883008    0.334262    2.512535    0.681058   -0.098537
# std     259.549777    0.472061    0.715818    0.466391    0.769449
# min       1.000000    0.000000    1.000000    0.000000   -2.025883
# 25%     220.250000    0.000000    2.000000    0.000000   -0.565736
# 50%     447.500000    0.000000    3.000000    1.000000   -0.104637
# 75%     673.500000    1.000000    3.000000    1.000000    0.270006
# max     891.000000    1.000000    3.000000    1.000000    1.893459
#
#             SibSp       Parch        Fare    Embarked
# count  718.000000  718.000000  718.000000  718.000000
# mean     0.413649    0.317549   -0.302242    1.611421
# std      0.855001    0.784792    0.266674    0.726646
# min      0.000000    0.000000   -0.648422    0.000000
# 25%      0.000000    0.000000   -0.489568    2.000000
# 50%      0.000000    0.000000   -0.411839    2.000000
# 75%      1.000000    0.000000   -0.126366    2.000000
# max      5.000000    6.000000    0.587429    2.000000
# PassengerId    447.500000
# Survived         0.000000
# Pclass           3.000000
# Sex              1.000000
# Age             -0.104637
# SibSp            0.000000
# Parch            0.000000
# Fare            -0.411839
# Embarked         2.000000
# dtype: float64
# PassengerId    259.549777
# Survived         0.472061
# Pclass           0.715818
# Sex              0.466391
# Age              0.769449
# SibSp            0.855001
# Parch            0.784792
# Fare             0.266674
# Embarked         0.726646
# dtype: float64

# %% [markdown]
# **STEP 4: Visualization ✅**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Histogram
df.hist(figsize=(10, 8))
plt.tight_layout()
plt.show()

# Boxplot for outlier detection
sns.boxplot(x=df['Fare'])
plt.show()

# Age distribution by survival
sns.histplot(data=df, x='Age', hue='Survived', multiple='stack')
plt.show()

# %% [markdown]
# **STEP 5: Pairplot or Correlation Matrix ✅**

# %%
# Pairplot
sns.pairplot(df[['Age', 'Fare', 'Pclass', 'Survived']])
plt.show()

# Correlation matrix
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.show()

# %% [markdown]
# **STEP 6: Analysis ✅**

# %%
sns.countplot(data=df, x='Pclass', hue='Survived')
plt.title("Survival by Passenger Class")
plt.show()

sns.countplot(data=df, x='Sex', hue='Survived')
plt.title("Survival by Gender")
plt.show()
